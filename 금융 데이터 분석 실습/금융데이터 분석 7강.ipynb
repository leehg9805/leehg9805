# %% [markdown]
# # 7강 데이터 시각화

# %%
# 7-1 pyplot 기초

import matplotlib.pyplot as plt

fig = plt.figure()
subplot = fig.add_subplot(1,1,1)
subplot.plot([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
subplot1 = fig.add_subplot(1,2,1)
subplot2 = fig.add_subplot(1,2,2)
subplot1.plot([1,2,3,4])
subplot2.plot([4,3,2,1])
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2,2)

axes[0][0].plot([1,2,3,4])
axes[0][1].plot([4,3,2,1])
axes[1][0].plot([1,2,2,1])
axes[1][1].plot([2,1,1,2])
plt.show()

# %%
import matplotlib.pyplot as plt 
    
plt.plot([1,2,3,4])
plt.show()

# %%
# 7-2 라인 차트

import matplotlib.pyplot as plt

plt.plot([2,1,1,2])
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[1,2,3,4]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [2,1,1,2])

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('matplotlib')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3,4], [2,1,1,2])

ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('title')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[1,2,3,4], label = 'ascending')
plt.plot([1,2,3,4], [4,3,2,1], label = 'descending')

plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
import platform

if platform.system() =='Darwin' :
    plt.rc('font', family='AppleGothic')
else :
    plt.rc('font', family='Malgun Gothic')

# %%
import pandas as pd
kospi = pd.read_excel('finace_data/kospi.xlsx', index_col="Date")
kospi
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-01-02  2010.00  2050.55  2053.45  2004.27  326370000.0 -0.0152
# 2019-01-03  1993.70  2011.81  2014.72  1991.65  427980000.0 -0.0081
# 2019-01-04  2010.25  1992.40  2011.56  1984.53  408990000.0  0.0083
# 2019-01-07  2037.10  2034.24  2048.06  2030.90  440190000.0  0.0134
# 2019-01-08  2025.27  2038.68  2042.70  2023.59  397830000.0 -0.0058
# ...             ...      ...      ...      ...          ...     ...
# 2021-08-23  3090.21  3086.81  3111.81  3064.65  570980000.0  0.0097
# 2021-08-24  3138.30  3119.70  3142.58  3115.23  586530000.0  0.0156
# 2021-08-25  3146.81  3148.13  3161.00  3124.25  624690000.0  0.0027
# 2021-08-26  3128.53  3151.30  3159.37  3121.04  727720000.0 -0.0058
# 2021-08-27  3133.90  3116.29  3143.01  3106.97  520670000.0  0.0017
#
# [658 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1,1,1)
ax.plot(kospi['Close'])

ax.set_xlabel('날짜')
ax.set_ylabel('코스피지수')
ax.set_title('2019년 이후 코스피지수')
plt.grid(True, axis='y')
plt.show()

# %%
import pandas as pd

df = pd.read_excel('finace_data/loan.xlsx', index_col=0, header=[0,1])
df.head()
# Out:
# 전년동월비(%)기준년월 대출고객수           대출잔액
#                 전체 1금융권 2금융권   전체  1금융권 2금융권
# '21.06         7.1  8.5  5.9  6.7   9.8  3.3
# '21.05         8.1  9.7  6.8  7.9  11.4  4.0
# '21.04         4.8  5.6  4.2  5.3   8.5  1.9
# '21.03         5.1  6.3  4.2  5.1   8.6  1.3
# '21.02         5.1  6.6  3.9  5.0   9.0  0.8

# %%
대출잔액 = df['대출잔액']
대출잔액 = 대출잔액[::-1]
대출잔액.head()
# Out:
#          전체  1금융권  2금융권
# '20.06  2.3   7.4  -2.7
# '20.07  2.0   6.9  -2.8
# '20.08  2.3   7.4  -2.7
# '20.09  2.1   6.6  -2.4
# '20.10  0.6   8.5  -7.2

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,8))
plt.plot(대출잔액.index, 대출잔액['전체'], marker='o', label='전체')
plt.plot(대출잔액.index, 대출잔액['1금융권'], marker='o', label='1금융권')
plt.plot(대출잔액.index, 대출잔액['2금융권'], marker='o', label='2금융권')

plt.rc('axes', unicode_minus=False)
plt.ylabel('(전년동월비,%)')
plt.legend()
plt.grid(True, axis='y')
plt.show()

# %%
# 7-3 막대 차트

import matplotlib.pyplot as plt

plt.bar([1,3,5,7,9], [2,3,2,2,8])
plt.show()

# %%
import pandas as pd

kospi = pd.read_excel("finace_data/kospi.xlsx", index_col="Date")
kospi2020 = kospi.loc['2020']
mean_kospi_2020 = kospi2020.resample('MS').mean()
mean_kospi_2020.head()
# Out:
#                   Close         Open         High          Low        Volume  \
# Date
# 2020-01-01  2203.442500  2207.549000  2218.408000  2192.597000  6.548040e+08
# 2020-02-01  2167.123500  2166.166000  2183.180500  2150.528500  6.982085e+08
# 2020-03-01  1786.746364  1794.281364  1824.905909  1751.699091  7.773055e+08
# 2020-04-01  1849.589000  1844.271500  1864.864000  1825.824000  1.051872e+09
# 2020-05-01  1965.174211  1963.487895  1975.821579  1949.060526  8.532689e+08
#
#               Change
# Date
# 2020-01-01 -0.001745
# 2020-02-01 -0.003080
# 2020-03-01 -0.004791
# 2020-04-01  0.005395
# 2020-05-01  0.002237

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(1,1,1)
month = [x.strftime('%y-%m') for x in mean_kospi_2020.index]
ax.bar(x=month, height = mean_kospi_2020['Volume'], width=0.5, color='skyblue')

plt.ticklabel_format(axis='y', style='plain')
plt.title("KOSPI 월별 평균 거래량(2020년)")
plt.xlabel('월')
plt.ylabel('평균 거래량')
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(1,1,1)
month = [x.strftime('%y-%m') for x in mean_kospi_2020.index]
ax.barh(y=month[::-1], width=mean_kospi_2020['Volume'][::-1], height = 0.5, color='#F88878')

plt.ticklabel_format(axis='x', style='plain')
plt.title("KOSPI 월별 평균 거래량(2020년)")
plt.xlabel('월')
plt.ylabel('평균 거래량')
plt.show()

# %%
# 히스토그램

import matplotlib.pyplot as plt

data = [1,2,2,3,3,3,4,4,4,4]
plt.hist(data)
plt.show()

# %%
import matplotlib.pyplot as plt

data = range(100)
(n, bins, patches) = plt.hist(data)
plt.show()

# %%
print(n)
print(bins)
print(patches)
# Out:
# [10. 10. 10. 10. 10. 10. 10. 10. 10. 10.]
# [ 0.   9.9 19.8 29.7 39.6 49.5 59.4 69.3 79.2 89.1 99. ]
# <BarContainer object of 10 artists>

# %%
import pandas as pd
kospi = pd.read_excel('finace_data/kospi.xlsx', index_col='Date')
kospi.head()
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-01-02  2010.00  2050.55  2053.45  2004.27  326370000.0 -0.0152
# 2019-01-03  1993.70  2011.81  2014.72  1991.65  427980000.0 -0.0081
# 2019-01-04  2010.25  1992.40  2011.56  1984.53  408990000.0  0.0083
# 2019-01-07  2037.10  2034.24  2048.06  2030.90  440190000.0  0.0134
# 2019-01-08  2025.27  2038.68  2042.70  2023.59  397830000.0 -0.0058

# %%
import matplotlib.pyplot as plt

n, bins, patches = plt.hist(x=kospi["Change"]*100, bins=20)
plt.grid()
plt.show()

# %%
# 7-5 지수화

import pandas as pd

sec = pd.read_excel('finace_data/sec.xlsx', index_col='Date')
skhynix = pd.read_excel('finace_data/skhynix.xlsx', index_col="Date")

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(1,1,1)
ax.plot(sec.index, sec['Close'], label="SEC")
ax.plot(sec.index, skhynix['Close'], label="SK hynix")
plt.title('삼성전자, SK하이닉스 2020년 가격 비교')
plt.legend()
plt.show()
# Out:
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt

sec_index = (sec['Close']/ sec['Close'][0])*100
skhynix_index = (skhynix["Close"]/ skhynix['Close'][0])*100

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(1,1,1)
ax.plot(sec.index, sec_index, label="SEC")
ax.plot(sec.index, skhynix_index, label="SK hynix")
plt.ylabel('가격지수')
plt.title("삼성전자, SK하이닉스 2020년 가격 비교")
plt.legend()
plt.show()
# Out:
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\acon\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 캔들 차트

# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b1-py3-none-any.whl (70 kB)
# Requirement already satisfied: matplotlib in c:\acon\lib\site-packages (from mplfinance) (3.4.3)
# Requirement already satisfied: pandas in c:\acon\lib\site-packages (from mplfinance) (1.3.4)
# Requirement already satisfied: numpy>=1.16 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\acon\lib\site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: six in c:\acon\lib\site-packages (from cycler>=0.10->matplotlib->mplfinance) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\acon\lib\site-packages (from pandas->mplfinance) (2021.3)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.9b1

# %%
import pandas as pd

df = pd.read_excel('finace_data/sec.xlsx', index_col =0)
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2020-12-23  72400  74000  72300  73900  19411326  0.022130
# 2020-12-24  74100  78800  74000  77800  32502870  0.052774
# 2020-12-28  79000  80100  78200  78700  40085044  0.011568
# 2020-12-29  78800  78900  77300  78300  30339449 -0.005083
# 2020-12-30  77400  81300  77300  81000  29417421  0.034483
#
# [248 rows x 6 columns]

# %%
import mplfinance as mpf

mpf.plot(data=df.loc['2020-12'], type='candle')

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
mc = mpf.make_marketcolors(
   up='r',
    down='b',
    edge="inherit",
    wick="inherit"
)

s = mpf.make_mpf_style(
    base_mpf_style='starsandstripes',
    marketcolors=mc,
    gridaxis='both',
    y_on_right=True
)

mpf.plot(data=df.iloc[:60], type='candle', style=s, figratio=(13,6))

# %%
mc =mpf.make_marketcolors(
 up='r',
 down='b',
 edge='inherit',
    wick='inherit',
    volume='inherit'
)

s = mpf.make_mpf_style(
 base_mpf_style='starsandstripes',
 marketcolors=mc,
gridaxis='both',
    y_on_right=True
)

mpf.plot(
    data= df.iloc[:60],
    type='candle',
    style=s,
    figratio=(13,6),
    volume=True,
    scale_width_adjustment=dict(volume=0.8, candle=1)
)

# %%
mpf.plot(
 data=df.iloc[:60],
    type='candle',
    mav=(5,20),
    style=s,
    figratio=(13,6),
    volume=True,
    scale_width_adjustment=dict(volume=0.8, candle=1)
)

# %%
import pandas as pd

kospi = pd.read_excel('finace_data/kospi.xlsx', index_col=0)
kospi['MA20'] = kospi['Close'].rolling(window=20).mean()
kospi['MA60'] = kospi['Close'].rolling(window=60).mean()
kospi['MA120'] = kospi['Close'].rolling(window=120).mean()
kospi.head()
# Out:
#               Close     Open     High      Low       Volume  Change  MA20  \
# Date
# 2019-01-02  2010.00  2050.55  2053.45  2004.27  326370000.0 -0.0152   NaN
# 2019-01-03  1993.70  2011.81  2014.72  1991.65  427980000.0 -0.0081   NaN
# 2019-01-04  2010.25  1992.40  2011.56  1984.53  408990000.0  0.0083   NaN
# 2019-01-07  2037.10  2034.24  2048.06  2030.90  440190000.0  0.0134   NaN
# 2019-01-08  2025.27  2038.68  2042.70  2023.59  397830000.0 -0.0058   NaN
#
#             MA60  MA120
# Date
# 2019-01-02   NaN    NaN
# 2019-01-03   NaN    NaN
# 2019-01-04   NaN    NaN
# 2019-01-07   NaN    NaN
# 2019-01-08   NaN    NaN

# %%
import matplotlib.pyplot as plt
import platform

if platform.system() == 'Darwin' :
    plt.rc('font', family='AppleGothic')
else :
    plt.rc('font', family = 'Malgun Gothic')
    
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1,1,1)


ax.plot(kospi['Close'], label='close')
ax.plot(kospi['MA20'], label='ma20')
ax.plot(kospi['MA60'], label='ma60')
ax.plot(kospi['MA120'], label='ma120')

ax.set_xlabel('날짜')
ax.set_ylabel('코스피지수')
ax.set_title('2019년 이후 코스피 지수')
ax.legend(loc='best')
plt.grid(True, axis='y')
plt.show()

# %%
import pandas as pd

kospi = pd.read_excel('finace_data/kospi.xlsx', index_col=0, usecols=[0,1,2])
kospi
# Out:
#               Close     Open
# Date
# 2019-01-02  2010.00  2050.55
# 2019-01-03  1993.70  2011.81
# 2019-01-04  2010.25  1992.40
# 2019-01-07  2037.10  2034.24
# 2019-01-08  2025.27  2038.68
# ...             ...      ...
# 2021-08-23  3090.21  3086.81
# 2021-08-24  3138.30  3119.70
# 2021-08-25  3146.81  3148.13
# 2021-08-26  3128.53  3151.30
# 2021-08-27  3133.90  3116.29
#
# [658 rows x 2 columns]

# %%
kospi.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
kospi.plot.line()
kospi.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
upward = kospi['Open'] <kospi['Close']
stationary = kospi['Open'] ==kospi['Close']
downward = kospi['Open'] >kospi['Close']

kospi.loc[upward,'category'] = '상승'
kospi.loc[stationary, 'category'] = '보합'
kospi.loc[downward, 'category'] = '하락'

how = {
    'category' : len
    
}
data = kospi.groupby('category').agg(how)
print(data)
# Out:
#           category
# category
# 상승             333
# 하락             325

# %%
import matplotlib.pyplot as plt
import platform

if platform.system() == 'Darwin' :
    plt.rc('font', family = 'AppleGothic')
else:
    plt.rc('font', family = 'Malgun Gothic')
data.plot.bar(legend=False)
# Out:
# <AxesSubplot:xlabel='category'>
