# %% [markdown]
# <a href="https://colab.research.google.com/github/leehg9805/leehg9805/blob/main/studypractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
df=pd.read_csv('cosmetics_.csv')

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df=pd.read_excel('cosmetics_.xlsx')

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df=pd.read_csv('cosmeticsKR_.csv', encoding='euc-kr')

# %%
df
# Out:
#      성별  결혼여부  교육  직업  소득  인지브랜드  구매량     구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 0     1     1   4   1   2      2    1    11000      2     1   1     1     2
# 1     2     1   4   9   2      1    4    30000      1     1   3     2     3
# 2     2     2   4   4   3      1    6   100000      3     2   3     2     2
# 3     2     2   4   7   5      2    6    65000      3     2   5     2     3
# 4     1     2   6   6   5      2    2    50000      2     2   3     2     3
# ..   ..   ...  ..  ..  ..    ...  ...      ...    ...   ...  ..   ...   ...
# 242   1     1   4   2   3      2    6     4000      1     1   1     1     4
# 243   2     2   4   4   2      1   10   150000      3     2   2     1     2
# 244   2     2   7   8   1      2    3   100000      1     2   1     1     5
# 245   1     1   4   6   1      3    2    20000      3     1   1     1     3
# 246   2     2   6  10   1      1   10  1000000      3     2   3     1     3
#
#      만족1  만족2  전반만족  재구매의향
# 0      5    2     2      2
# ...

# %%
df.head(5)
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0       1         1    4    1        2      2      1   11000         2
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
# 3       2         2    4    7        5      2      6   65000         3
# 4       1         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase
# 0           2
# 1           4
# 2           4
# 3           4
# 4           3

# %%
df.tail(5)
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 242           1     1      1         4         2         1          1
# 243           2     2      1         2         3         4          4
# 244           2     1      1         5         2         5          4
# 245           1     1      1         3         4         3          3
# 246           2     3      1         3         2         3          3
#
#      repurchase
# 242           1
# 243           4
# 244           4
# 245           2
# ...

# %%
df[1:5]
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
# 3       2         2    4    7        5      2      6   65000         3
# 4       1         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase
# 1           4
# 2           4
# 3           4
# 4           3

# %%
df[:3]
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0       1         1    4    1        2      2      1   11000         2
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
#
#    repurchase
# 0           2
# 1           4
# 2           4

# %%
df[245:]
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 245           1     1      1         3         4         3          3
# 246           2     3      1         3         2         3          3
#
#      repurchase
# 245           2
# 246           3

# %%
df[100:110]
# Out:
#      gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 100       1         2    8    3        6      2      3  100000         3
# 101       2         1    4    8        1      1      2  100000         3
# 102       2         2    4    7        4      2      5   30000         3
# 103       2         2    2    7        3      2      2  100000         3
# 104       2         2    8    3        6      2      2  300000         3
# 105       1         2    6    2        6      2      2   20000         3
# 106       2         2    6    4        3      2      3  150000         2
# 107       2         1    4    4        2      1      2   30000         3
# 108       2         2    4    3        3      1      3  250000         2
# 109       2         2    4    5        5      8      3  200000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 100           2     3      2         3         1         1          3
# ...

# %%
df1=df[df.columns[[1,3,10]]]

# %%
df1
# Out:
#      marriage  job  skin
# 0           1    1     1
# 1           1    9     3
# 2           2    4     3
# 3           2    7     5
# 4           2    6     3
# ..        ...  ...   ...
# 242         1    2     1
# 243         2    4     2
# 244         2    8     1
# 245         1    6     1
# 246         2   10     3
#
# [247 rows x 3 columns]

# %%
df2=df.loc[:,'decision':'location']

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df.iloc[1:7,0:2] #행열 모두 선택
# Out:
#    gender  marriage
# 1       2         1
# 2       2         2
# 3       2         2
# 4       1         2
# 5       2         2
# 6       2         1

# %%
df.at[5,'amount']
# Out:
# 100000

# %%
df_colums=df.copy()

# %%
df_colums
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df_columns=df_colums[['gender', 'marriage','edu','job','mincome']]

# %%
df_columns
# Out:
#      gender  marriage  edu  job  mincome
# 0         1         1    4    1        2
# 1         2         1    4    9        2
# 2         2         2    4    4        3
# 3         2         2    4    7        5
# 4         1         2    6    6        5
# ..      ...       ...  ...  ...      ...
# 242       1         1    4    2        3
# 243       2         2    4    4        2
# 244       2         2    7    8        1
# 245       1         1    4    6        1
# 246       2         2    6   10        1
#
# [247 rows x 5 columns]

# %%
df_columns.rename(columns={'job':'ocoupation'},inplace=True)

# %%
df_columns
# Out:
#      gender  marriage  edu  ocoupation  mincome
# 0         1         1    4           1        2
# 1         2         1    4           9        2
# 2         2         2    4           4        3
# 3         2         2    4           7        5
# 4         1         2    6           6        5
# ..      ...       ...  ...         ...      ...
# 242       1         1    4           2        3
# 243       2         2    4           4        2
# 244       2         2    7           8        1
# 245       1         1    4           6        1
# 246       2         2    6          10        1
#
# [247 rows x 5 columns]

# %%
df['text-included price']=df['amount']*1.1

# %%
df['sum']=df['amount']+df['count']

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
import numpy as np

# %%
df['log']=np.log(df['amount'])
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
del df['text-included price']

# %%
del df['sum']

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df_gender=df[(df['gender']==1)]

# %%
df_gender
# Out:
#      gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0         1         1    4    1        2      2      1   11000         2
# 4         1         2    6    6        5      2      2   50000         2
# 7         1         1    6    4        5      4     10   39000         3
# 11        1         1    2    5        3      2      1   30000         3
# 14        1         2    4    4        6      2      2   60000         3
# ..      ...       ...  ...  ...      ...    ...    ...     ...       ...
# 237       1         2    4    4        3      2      2   50000         1
# 238       1         2    4    4        5      2      1   80000         2
# 241       1         1    2    1        2      2      5    3000         1
# 242       1         1    4    2        3      2      6    4000         1
# 245       1         1    4    6        1      3      2   20000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df_recount=df[(df['count']<10) & (df['count']>1)]

# %%
df_recount
# Out:
#      gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 1         2         1    4    9        2      1      4   30000         1
# 2         2         2    4    4        3      1      6  100000         3
# 3         2         2    4    7        5      2      6   65000         3
# 4         1         2    6    6        5      2      2   50000         2
# 5         2         2    2    7        3      1      2  100000         2
# ..      ...       ...  ...  ...      ...    ...    ...     ...       ...
# 240       2         2    7    7        4      1      2  200000         2
# 241       1         1    2    1        2      2      5    3000         1
# 242       1         1    4    2        3      2      6    4000         1
# 244       2         2    7    8        1      2      3  100000         1
# 245       1         1    4    6        1      3      2   20000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df_recount=df[(df['count']<10) | (df['count']>1)]

# %%
df_recount
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df.head(5)
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0       1         1    4    1        2      2      1   11000         2
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
# 3       2         2    4    7        5      2      6   65000         3
# 4       1         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase        log
# 0           2   9.305651
# 1           4  10.308953
# 2           4  11.512925
# ...

# %%
df['edu']. value_counts(sort=False)
# Out:
# 4    136
# 6     29
# 2     30
# 7     15
# 8     26
# 3      9
# 5      2
# Name: edu, dtype: int64

# %%
def edu_groups(series):
    if series==2:
        return 1
    elif series==3 or series==4:
        return 2
    elif series>=5:
        return 3

# %%
df['eduM']=df['edu'].apply(edu_groups)

# %%
df.head()
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0       1         1    4    1        2      2      1   11000         2
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
# 3       2         2    4    7        5      2      6   65000         3
# 4       1         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase        log  eduM
# 0           2   9.305651     2
# 1           4  10.308953     2
# 2           4  11.512925     2
# ...

# %%
df['eduM'].value_counts(sort=False)
# Out:
# 2    145
# 3     72
# 1     30
# Name: eduM, dtype: int64
